# %%
import time, datetime, os
print('DIAG3_START', flush=True)
for i in range(2000):
    with open('/kaggle/working/live.txt','a') as f:
        f.write(f'{i} {datetime.datetime.utcnow()} alive\n')
    time.sleep(15)
print('DIAG3_DONE', flush=True)
