# %%
print('DIAG_MARKER', flush=True)
r = 'hello from diag'
print(r, flush=True)

# %%
import time
print('DIAG_GPU_START', flush=True)
# !nvidia-smi
print('DIAG_GPU_END', flush=True)
while True:
    time.sleep(60)
    print('alive', flush=True)
