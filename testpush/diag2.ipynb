# %%
print('DIAG2_MARKER', flush=True)
import socket, datetime, os
with open('/kaggle/working/diag_out.txt','w') as f:
    f.write('diag2 ok ' + str(datetime.datetime.utcnow()) + '\n')
print('DIAG2_WROTE', os.path.exists('/kaggle/working/diag_out.txt'), flush=True)
